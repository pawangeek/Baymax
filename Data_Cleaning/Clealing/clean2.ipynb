# %%
import pandas as pd
import numpy as np
data = pd.read_csv("final.csv",encoding = 'unicode_escape')

# %%
data.shape
# Out:
# (1804, 80)

# %%
data.drop(['Unnamed: 0','1'],axis=1,inplace=True)

# %%
data_new = data.replace(np.nan, '', regex=True)

# %%
data_new = data_new.replace(r'\\n',' ', regex=True)

# %%
data_new.sample(10)
# Out:
#                                                       2  \
# 1591                       Abdominal pain upper abdomen
# 1778                                 Breathing may stop
# 1405                                      Bloody sputum
# 304
# 1497                                     Blurred vision
# 421   Soft areas of the skull especially along the s...
# 1469  Are bald with small black dots due to hair tha...
# 351                                   Confusion or coma
# 407                                        Heart murmur
# 1752  Difficulty performing tasks that used to come ...
#
#                                                       3  \
# 1591                                              Cough
# 1778                                    Rapid breathing
# 1405                             Difficulty breathing\n
# 304
# 1497                    Eye pain and tenderness  severe
# 421                           Soft areas pop in and out
# ...

# %%
columns = list(data)

# %%
#for i in columns:
 #   mask = (data[i].str.len() >= 3)
  #  data[i] = data[i].loc[mask]

# %%
data_new.shape
# Out:
# (1804, 78)

# %%
#word=['Symptomns','Symptom','symptom','symptoms']
#pattern = '|'.join(word)

# %%
#pattern

# %%
#for i in columns:
 #   data[i] = data[i][~data[i].str.contains(pattern,case=False,na=False)]

# %%
for i in columns:
    data_new[i] = data_new[i].str.strip()

# %%
for i in columns:
    mask = (data_new[i].str.len() >= 3)
    data_new[i] = data_new[i].loc[mask]

# %%
#data.shape

# %%
data_new.to_csv("final.csv")

# %%
for i in columns:
    data_new[i].replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)

# %%
data_new.to_csv("final.csv")

# %%
latest = pd.read_csv("new_ieee.csv")

# %%
import nltk
from nltk.corpus import stopwords

# %%
latest.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1,inplace=True)

# %%
latest=latest.apply(lambda x: x.astype(str).str.lower())

# %%
new=set(stopwords.words('english'))

# %%
new=list(new)

# %%
df = pd.DataFrame(new) 
data_dict = df.to_dict()

# %%
columns = list(data)

# %%
for i in columns:
    for w in new[:]:
        latest[i] = latest[i][~latest[i].str.startswith(w,na=False)]

# %%
latest.shape
# Out:
# (1804, 79)

# %%
latest.head()
# Out:
#                 disease_name  \
# 0           aarskog syndrome
# 1              aase syndrome
# 2  abdominal aortic aneurysm
# 3  abnormal uterine bleeding
# 4        abo incompatibility
#
#                                                    2  \
# 0                                                NaN
# 1                                                NaN
# 2                        pain in the abdomen or back
# 3  bleeding or spotting from the vagina between p...
# 4                                      low back pain
#
#                                                    3       4  \
# 0                      bulge in the groin or scrotum     NaN
# 1                                       cleft palate     NaN
# 2                                                NaN     NaN
# 3  periods that occur less than 28 days apart mor...     NaN
# 4                                     blood in urine  chills
#
#                            5  \
# 0                        NaN
# ...

# %%
latest.to_csv("ieee.csv")
